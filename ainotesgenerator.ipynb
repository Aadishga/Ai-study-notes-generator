# %%
pip install google-generativeai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import google.generativeai as genai
import os
from datetime import datetime

# %%
import google.generativeai as genai
from datetime import datetime

API_KEY = "YOUR_GEMINI_API_KEY_HERE"
genai.configure(api_key=API_KEY)
model = genai.GenerativeModel("gemini-3.5-flash")

def generate_study_notes(topic, level="beginner"):
    print(f"\n📚 Generating notes for: '{topic}' [{level}]...")
    prompt = f"""You are an expert educational content writer.
Create structured study notes on: {topic}
Level: {level}

Write these sections:
1. SUMMARY (3-4 sentences)
2. KEY CONCEPTS (5 bullet points)
3. IMPORTANT DEFINITIONS (4 terms)
4. REAL WORLD EXAMPLE (1 paragraph)
5. MINI QUIZ (3 questions with answers)
6. REMEMBER THIS (1 key takeaway)

Keep language simple for a {level} student."""

    response = model.generate_content(prompt)
    notes = response.text.strip()
    print(notes)
    
    filename = f"notes_{topic.replace(' ','_').lower()}.txt"
    with open(filename, "w", encoding="utf-8") as f:
        f.write(notes)
    print(f"\n💾 Saved → {filename}")

generate_study_notes("einstein theory", "beginner")
# Out:
# 📚 Generating notes for: 'einstein theory' [beginner]...
# # Study Notes: Einstein’s Theory of Relativity
#
# ---
#
# ### 1. SUMMARY
# Albert Einstein’s famous Theory of Relativity completely changed how we understand space, time, and gravity. Instead of space and time being separate and unchanging, Einstein showed that they are woven together into a single, flexible fabric called "spacetime." He explained that gravity is not a mysterious pulling force, but rather the bending of this spacetime fabric by heavy objects like planets and stars. Ultimately, his theory proved that how we experience time and space depends entirely on how fast we are moving.
#
# ---
#
# ### 2. KEY CONCEPTS
# * **The Speed of Light is the Limit:** Nothing in the universe can travel faster than the speed of light, and light always travels at the exact same speed, no matter how fast you are moving toward or away from it.
# ...
